# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook uses the NAMCS for the years 2005-2016 in SPSS (.sav files) from https://www.cdc.gov/nchs/ahcd/datasets_documentation_related.htm. More SPSS data is available from years 2002-2016, and STATA (2000-2016; .do, .dct, .exe files).
#
# Google Health Searches data is available for years 2004-2017, so the goal here is to see how Google Health Searches correlate with prevalence/ proportion (?) of diseases including Cardiovascular Disearse, Stroke, Cancer, Diabetes, Obesity, and Depression in the years 2005-2016. 2004 data ommitted for this project due to large differences in survey labels.

# %%
import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
# !pip install pyreadstat
import pyreadstat
from collections import Counter
import re
import time
# Out:
# Collecting pyreadstat
#   Downloading https://files.pythonhosted.org/packages/88/9c/0dd8def223f1cf5dcba1efd27532fe22db48bad117a9cbb74ab507882ab2/pyreadstat-0.2.9-cp36-cp36m-manylinux1_x86_64.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 2.8MB/s
# Installing collected packages: pyreadstat
# Successfully installed pyreadstat-0.2.9

# %%
# Mount Google Drive files to Colab
# SPSS Data files (.sav format) were uploaded to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Read SPSS file

# %%
# Create list of all years and filenames for the CDC data
years = []
filenames = []

for i in range(5,17):
    if i < 10:
        yr = '200' + str(i)
        temp = 'namcs0' + str(i) + '-spss.sav'
    else:
        yr = '20' + str(i)
        temp = 'namcs' + yr + '-spss.sav'    

    years.append(yr)
    filenames.append(temp)

print(years) 
print(filenames)
# Out:
# ['2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']
# ['namcs05-spss.sav', 'namcs06-spss.sav', 'namcs07-spss.sav', 'namcs08-spss.sav', 'namcs09-spss.sav', 'namcs2010-spss.sav', 'namcs2011-spss.sav', 'namcs2012-spss.sav', 'namcs2013-spss.sav', 'namcs2014-spss.sav', 'namcs2015-spss.sav', 'namcs2016-spss.sav']

# %%
# This study will use 12 years of data from 2005 - 2016

len(filenames)
# Out:
# 12

# %% [markdown]
# # Data Cleaning / Wrangling

# %%
# Initialize dataframe and dictionary with total counts
trim_df = pd.DataFrame()
all_years_counts = dict()
start = time.time()

# Loop to concatenate (vertically stack) SPSS data files for all years
for ind in range(len(filenames)):
  ### Read in the data
  file = filenames[ind]
  path = '/content/drive/My Drive/Capstone1/' + file
  #file='/content/drive/My Drive/Capstone1/namcs2016-spss.sav' 
  df, meta = pyreadstat.read_sav(path, apply_value_formats=True, formats_as_category=True)
 
  # Extract the year from filename
  temp = re.findall(r'\d{2,4}', file) # find all digits in file name that are 2-4 digits long
  if len(temp[0]) == 4:
      year = int(temp[0])
  else:
      year = int('20' + temp[0])

  print('Completed reading in data from the year', year)
  print('The shape of the dataframe is', df.shape)
  
  # Create a column for year
  df['YEAR'] = year
  
  # Create subset, extract only the columns that are relevant to project
  if year < 2012:
    # For 2005-2011 datasets
    colnames_sub =  ['YEAR', 'VMONTH', 'AGE', 'AGER', 'SEX', 'PATWT',
                    'REGION', 'RETYPOFF', 'MSA',
                    'RFV1', 'RFV2', 'RFV3', 'PRIMCARE', 'REFER', 
                    'MAJOR', 'DIAG1', 'DIAG2', 'DIAG3',
                    'TIMEMD', 'REFOTHMD', 
                    'CANCER', 'DIABETES', 'IHD', 'CHF', 'CEBVD',
                    'DEPRN', 'OBESITY']
    subset = df[colnames_sub]
    # Replace 'IHD' with 'CAD' column name
    subset.rename(columns = {'IHD':'CAD'}, inplace=True)
    
  elif year == 2012 or year == 2013:
    # For 2012-2013 datasets
    colnames_sub =  ['YEAR', 'VMONTH', 'AGE', 'AGER', 'SEX', 'PATWT',
                    'REGIONOFF', 'RETYPOFFR', 'MSA',
                    'RFV1', 'RFV2', 'RFV3', 'PRIMCARE', 'REFER', 
                    'MAJOR', 'DIAG1', 'DIAG2', 'DIAG3',
                    'TIMEMD', 'REFOTHMD', 
                    'CANCER', 'DIABETES', 'IHD', 'CHF', 'CEBVD', 
                    'DEPRN', 'OBESITY']
    subset = df[colnames_sub]
    # Replace 'IHD' with 'CAD' column name, 'REGIONOFF' with 'REGION', etc.
    subset.rename(columns = {'IHD':'CAD', 'REGIONOFF':'REGION', 'RETYPOFFR':'RETYPOFF'}, inplace=True)

  else:
    # For 2014-2016 datasets
    colnames_sub =  ['YEAR', 'VMONTH', 'AGE', 'AGER', 'SEX', 'PATWT',
                    'REGIONOFF', 'RETYPOFFR', 'MSA',
                    'RFV1', 'RFV2', 'RFV3', 'PRIMCARE', 'REFER', 
                    'MAJOR', 'DIAG1', 'DIAG2', 'DIAG3',
                    'TIMEMD', 'REFOTHMD', 
                    'CANCER', 'DIABTYP1', 'DIABTYP2', 'DIABTYP0',
                    'CAD', 'CHF', 'CEBVD',
                    'DEPRN', 'OBESITY']
    subset = df[colnames_sub]
    subset.rename(columns = {'REGIONOFF':'REGION', 'RETYPOFFR':'RETYPOFF'}, inplace=True)
    bool1 = subset['DIABTYP1'] == 'Yes'
    bool2 = subset['DIABTYP2'] == 'Yes'
    bool3 = subset['DIABTYP0'] == 'Yes'
    db = subset[bool1 | bool2 | bool3]
    # Create new column 'DIABETES' to consolidate 'DIABTYP1', 'DIABTYP2', 'DIABTYP0'
    subset['DIABETES'] = 'No' # default column value
    # unless patient has Diabetes type 1, 2, or 'unspecified' Diabetes
    for i in db.index:
      subset.loc[i,'DIABETES'] = 'Yes'
    # Remove 'DIABTYP1', 'DIABTYP2', 'DIABTYP0' columns
    subset = subset.drop(['DIABTYP1', 'DIABTYP2', 'DIABTYP0'], axis=1)
    # Reorder columns
    subset = subset[['YEAR', 'VMONTH', 'AGE', 'AGER', 'SEX', 'PATWT', 'REGION',
       'RETYPOFF', 'MSA', 'RFV1', 'RFV2', 'RFV3', 'PRIMCARE', 'REFER',
       'MAJOR', 'DIAG1', 'DIAG2', 'DIAG3', 'TIMEMD', 'CANCER', 'DIABETES',
       'CAD', 'CHF', 'CEBVD', 'DEPRN', 'OBESITY']]

  #Count the occurences of each disease, and build a dictionary for each year
  #if year < 2014:
    # For 2005-2013 datasets, list of disease names
  diags = ['CANCER', 'DIABETES', 'CAD', 'CHF', 'CEBVD', 'DEPRN', 'OBESITY']
  d0 = subset[diags[0]]=='Yes'
  d1 = subset[diags[1]]=='Yes'
  d2 = subset[diags[2]]=='Yes'
  d3 = subset[diags[3]]=='Yes'
  d4 = subset[diags[4]]=='Yes'
  d5 = subset[diags[5]]=='Yes'
  d6 = subset[diags[6]]=='Yes'
  temp_df = subset[d0 | d1 | d2 | d3 | d4 | d5 | d6]
  trim_df = pd.concat([trim_df, temp_df], axis=0, ignore_index=True, sort=False)
  
  n_all = dict() # initialize dictionary to count diseases for current year in loop
  for i in diags:
    n_yes = len(subset[subset[i] == 'Yes'])
    n_all[i] = n_yes
    
  # Add dictionary to large dictionary with all years
  all_years_counts[year] = n_all
  tcheck = time.time()
  print('Time to complete loop', ind, ':', tcheck-start)

print(all_years_counts)
print(trim_df.head())
# Out:
# Completed reading in data from the year 2005
# The shape of the dataframe is (25665, 354)
# Time to complete loop
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
# 0 : 11.589228391647339
# Completed reading in data from the year 2006
# The shape of the dataframe is (29392, 449)
# Time to complete loop 1 : 30.226481676101685
# Completed reading in data from the year 2007
# The shape of the dataframe is (32778, 453)
# Time to complete loop 2 : 52.9420280456543
# Completed reading in data from the year 2008
# The shape of the dataframe is (28741, 453)
# Time to complete loop 3 : 72.48630857467651
# Completed reading in data from the year 2009
# The shape of the dataframe is (32281, 440)
# Time to complete loop 4 : 93.87728476524353
# Completed reading in data from the year 2010
# The shape of the dataframe is (31229, 481)
# Time to complete loop 5 : 116.93627572059631
# Completed reading in data from the year 2011
# The shape of the dataframe is (30872, 480)
# Time to complete loop 6 : 139.44848155975342
# Completed reading in data from the year 2012
# The shape of the dataframe is (76330, 624)
# Time to complete loop 7 : 222.81648993492126
# Completed reading in data from the year 2013
# The shape of the dataframe is (54873, 616)
# Time to complete loop 8 : 280.95563220977783
# Completed reading in data from the year 2014
# The shape of the dataframe is (45710, 1104)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Time to complete loop 9 : 411.74905228614807
# Completed reading in data from the year 2015
# The shape of the dataframe is (28332, 1096)
# Time to complete loop 10 : 487.84825706481934
# Completed reading in data from the year 2016
# The shape of the dataframe is (13165, 1031)
# Time to complete loop 11 : 519.5233306884766
# {2005: {'CANCER': 1619, 'DIABETES': 2266, 'CAD': 1233, 'CHF': 431, 'CEBVD': 574, 'DEPRN': 2704, 'OBESITY': 1651}, 2006: {'CANCER': 2270, 'DIABETES': 2882, 'CAD': 1403, 'CHF': 499, 'CEBVD': 530, 'DEPRN': 2858, 'OBESITY': 1986}, 2007: {'CANCER': 2996, 'DIABETES': 3438, 'CAD': 1638, 'CHF': 601, 'CEBVD': 631, 'DEPRN': 3102, 'OBESITY': 2010}, 2008: {'CANCER': 1645, 'DIABETES': 2955, 'CAD': 1318, 'CHF': 462, 'CEBVD': 562, 'DEPRN': 2727, 'OBESITY': 1813}, 2009: {'CANCER': 1892, 'DIABETES': 3873, 'CAD': 1639, 'CHF': 668, 'CEBVD': 662, 'DEPRN': 3458, 'OBESITY': 2576}, 2010: {'CANCER': 2661, 'DIABETES': 3434, 'CAD': 1314, 'CHF': 542, 'CEBVD': 526, 'DEPRN': 3130, 'OBESITY': 2321}, 2011: {'CANCER': 2699, 'DIABETES': 3649, 'CAD': 1376, 'CHF': 633, 'CEBVD': 743, 'DEPRN': 3815, 'OBESITY': 2430}, 2012: {'CANCER': 5479, 'DIABETES': 8138, 'CAD': 2461, 'CHF': 1219, 'CEBVD': 1420, 'DEPRN': 7124, 'OBESITY': 4639}, 2013: {'CANCER': 3750, 'DIABETES': 6399, 'CAD': 1968, 'CHF': 913, 'CEBVD': 1000, 'DEPRN': 5415, 'OBESITY': 3470}, 2014: {'CANCER': 3438, 'DIABETES': 5700, 'CAD': 3024, 'CHF': 769, 'CEBVD': 906, 'DEPRN': 4687, 'OBESITY': 3340}, 2015: {'CANCER': 2469, 'DIABETES': 3481, 'CAD': 1829, 'CHF': 390, 'CEBVD': 585, 'DEPRN': 2743, 'OBESITY': 1838}, 2016: {'CANCER': 1257, 'DIABETES': 1528, 'CAD': 830, 'CHF': 243, 'CEBVD': 306, 'DEPRN': 1136, 'OBESITY': 782}}
#    YEAR   VMONTH AGE         AGER     SEX  ...  CAD CHF CEBVD DEPRN OBESITY
# 0  2005  January  62  45-64 years    Male  ...   No  No    No    No      No
# 1  2005    April  59  45-64 years  Female  ...   No  No    No    No     Yes
# 2  2005    April  29  25-44 years    Male  ...   No  No    No   Yes      No
# 3  2005    April  29  25-44 years    Male  ...   No  No    No    No     Yes
# 4  2005    April  39  25-44 years    Male  ...   No  No    No    No     Yes
#
# [5 rows x 27 columns]

# %%
print(trim_df.info())
trim_df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142286 entries, 0 to 142285
# Data columns (total 27 columns):
# YEAR        142286 non-null int64
# VMONTH      142286 non-null category
# AGE         142286 non-null object
# AGER        142286 non-null category
# SEX         142286 non-null category
# PATWT       142286 non-null float64
# REGION      142286 non-null category
# RETYPOFF    142286 non-null object
# MSA         142286 non-null category
# RFV1        142286 non-null object
# RFV2        142286 non-null object
# RFV3        142286 non-null object
# PRIMCARE    142286 non-null category
# REFER       142286 non-null category
# MAJOR       142286 non-null object
# DIAG1       142286 non-null object
# DIAG2       142286 non-null object
# DIAG3       142286 non-null object
# TIMEMD      142286 non-null object
# REFOTHMD    111930 non-null object
# CANCER      142286 non-null category
# DIABETES    142286 non-null object
# CAD         142286 non-null category
# CHF         142286 non-null category
# CEBVD       142286 non-null category
# DEPRN       142286 non-null category
# OBESITY     142286 non-null category
# dtypes: category(13), float64(1), int64(1), object(12)
# memory usage: 17.0+ MB
# None
#         YEAR   VMONTH AGE               AGER  ... CHF  CEBVD DEPRN OBESITY
# 142281  2016  January  69        65-74 years  ...  No     No    No      No
# 142282  2016  January  66        65-74 years  ...  No     No    No      No
# 142283  2016  January  80  75 years and over  ...  No     No    No      No
# 142284  2016  January  76  75 years and over  ...  No     No   Yes      No
# 142285  2016  January  73        65-74 years  ...  No     No    No      No
#
# [5 rows x 27 columns]

# %% [markdown]
# # Saving Data

# %%
### Save the trim_df as csv and download

#trim_df.to_csv('cdc_namcs_trimmed.csv') 

#from google.colab import files

#files.download('cdc_namcs_trimmed.csv')

# %%
### all_years_counts dictionary
print(all_years_counts)
# Out:
# {2005: {'CANCER': 1619, 'DIABETES': 2266, 'CAD': 1233, 'CHF': 431, 'CEBVD': 574, 'DEPRN': 2704, 'OBESITY': 1651}, 2006: {'CANCER': 2270, 'DIABETES': 2882, 'CAD': 1403, 'CHF': 499, 'CEBVD': 530, 'DEPRN': 2858, 'OBESITY': 1986}, 2007: {'CANCER': 2996, 'DIABETES': 3438, 'CAD': 1638, 'CHF': 601, 'CEBVD': 631, 'DEPRN': 3102, 'OBESITY': 2010}, 2008: {'CANCER': 1645, 'DIABETES': 2955, 'CAD': 1318, 'CHF': 462, 'CEBVD': 562, 'DEPRN': 2727, 'OBESITY': 1813}, 2009: {'CANCER': 1892, 'DIABETES': 3873, 'CAD': 1639, 'CHF': 668, 'CEBVD': 662, 'DEPRN': 3458, 'OBESITY': 2576}, 2010: {'CANCER': 2661, 'DIABETES': 3434, 'CAD': 1314, 'CHF': 542, 'CEBVD': 526, 'DEPRN': 3130, 'OBESITY': 2321}, 2011: {'CANCER': 2699, 'DIABETES': 3649, 'CAD': 1376, 'CHF': 633, 'CEBVD': 743, 'DEPRN': 3815, 'OBESITY': 2430}, 2012: {'CANCER': 5479, 'DIABETES': 8138, 'CAD': 2461, 'CHF': 1219, 'CEBVD': 1420, 'DEPRN': 7124, 'OBESITY': 4639}, 2013: {'CANCER': 3750, 'DIABETES': 6399, 'CAD': 1968, 'CHF': 913, 'CEBVD': 1000, 'DEPRN': 5415, 'OBESITY': 3470}, 2014: {'CANCER': 3438, 'DIABETES': 5700, 'CAD': 3024, 'CHF': 769, 'CEBVD': 906, 'DEPRN': 4687, 'OBESITY': 3340}, 2015: {'CANCER': 2469, 'DIABETES': 3481, 'CAD': 1829, 'CHF': 390, 'CEBVD': 585, 'DEPRN': 2743, 'OBESITY': 1838}, 2016: {'CANCER': 1257, 'DIABETES': 1528, 'CAD': 830, 'CHF': 243, 'CEBVD': 306, 'DEPRN': 1136, 'OBESITY': 782}}

# %%
### Convert all_year_counts dictionary to DataFrame
count_df = pd.DataFrame.from_dict(all_years_counts, orient='index')

### Convert DataFrame to CSV                      
#count_df.to_csv('all_counts.csv')

### Download file
from google.colab import files
files.download('all_counts.csv')

# %% [markdown]
# # Other / Testing

# %%
''' 
### Ended up accessing data files that were uploaded to Google Drive, instead of local computer files
# Upload data file from local computer here
from google.colab import files

start = time.time()

uploaded2 = files.upload()

for fn in uploaded2.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded2[fn])))
  
end = time.time()
print('The time to load file was', end - start)
'''
# Out:
#      <input type="file" id="files-c9a8f731-8ef8-40bf-950a-726bc5e17e5a" name="files[]" multiple disabled />
#      <output id="result-c9a8f731-8ef8-40bf-950a-726bc5e17e5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving namcs2016-spss.sav to namcs2016-spss.sav
# User uploaded file "namcs2016-spss.sav" with length 23468228 bytes
# The time to load file was 204.70199275016785

# %%
# Meta data from the SPSS file
'''
print(meta.column_names)
print(meta.column_labels)
print(meta.variable_to_label)
print(meta.value_labels)
'''
# Out:
# ['VMONTH', 'VDAYR', 'AGE', 'AGER', 'AGEDAYS', 'SEX', 'PREGNANT', 'GESTWK', 'ETHUN', 'RACEUN', 'ETHIM', 'RACER', 'RACERETH', 'NOPAY', 'PAYPRIV', 'PAYMCARE', 'PAYMCAID', 'PAYWKCMP', 'PAYSELF', 'PAYNOCHG', 'PAYOTH', 'PAYDK', 'PAYTYPER', 'USETOBAC', 'INJURY', 'INJR1', 'INJR2', 'INJPOISAD', 'INJPOISADR1', 'INJPOISADR2', 'INTENT', 'INJDET_TRD', 'INJDETR1_TRD', 'INJDETR2_TRD', 'RFV1', 'RFV2', 'RFV3', 'RFV13D', 'RFV23D', 'RFV33D', 'PRIMCARE', 'REFER', 'SENBEFOR', 'PASTVIS', 'MAJOR', 'DIAG1', 'PRDIAG1', 'DIAG2', 'PRDIAG2', 'DIAG3', 'PRDIAG3', 'DIAG13D', 'DIAG23D', 'DIAG33D', 'DIAG1R', 'DIAG2R', 'DIAG3R', 'ARTHRTIS', 'ASTHMA', 'ASTH_SEV', 'ASTH_CON', 'CANCER', 'CASTAGE', 'CEBVD', 'COPD', 'CRF', 'CHF', 'DEPRN', 'DIABETES', 'HYPLIPID', 'HTN', 'IHD', 'OBESITY', 'OSTPRSIS', 'NOCHRON', 'TOTCHRON', 'HTTAKE', 'HTIN', 'WTTAKE', 'WTLB', 'BMI', 'TEMPTAKE', 'TEMPF', 'BLODPRES', 'BPSYS', 'BPDIAS', 'SERVICES', 'BREAST', 'DEPRESS', 'FOOT', 'PHYSICAL', 'NEURO', 'PELVIC', 'RECTAL', 'RETINAL', 'SKIN', 'CBC', 'GLUCOSE', 'HGBA', 'CHOLEST', 'PSA', 'ANYIMAGE', 'BONEDENS', 'CATSCAN', 'ECHOCARD', 'OTHULTRA', 'MAMMO', 'MRI', 'XRAY', 'OTHIMAGE', 'AUDIO', 'BIOPSY', 'BIOPROV', 'CARDIAC', 'CHLAMYD', 'COLON', 'EKG', 'EEG', 'EMG', 'EXCISION', 'EXCIPROV', 'FETAL', 'HIVTEST', 'HPVDNA', 'PAP', 'PEAK', 'PREGTEST', 'SIGMOID', 'SIGPROV', 'SPIRO', 'TONO', 'URINE', 'SIGCOLON', 'CSW', 'CAM', 'DME', 'HOMEHLTH', 'MENTAL', 'PT', 'PSYCHOTH', 'RADTHER', 'WOUND', 'ASTHMAED', 'DIETNUTR', 'EXERCISE', 'FAMPLAN', 'GRWTHDEV', 'INJPREV', 'STRESMGT', 'TOBACED', 'WTREDUC', 'OTHSERV', 'PROC1', 'PROC2', 'PROC3', 'PROC4', 'PROC5', 'PROC6', 'PROC7', 'PROC8', 'PROC9', 'PROC13D', 'PROC23D', 'PROC33D', 'PROC43D', 'PROC53D', 'PROC63D', 'PROC73D', 'PROC83D', 'PROC93D', 'PROC12D', 'PROC22D', 'PROC32D', 'PROC42D', 'PROC52D', 'PROC62D', 'PROC72D', 'PROC82D', 'PROC92D', 'PROC1R', 'PROC2R', 'PROC3R', 'PROC4R', 'PROC5R', 'PROC6R', 'PROC7R', 'PROC8R', 'PROC9R', 'EXAM', 'SERVCNT', 'ALLSERV', 'MED', 'MED1', 'MED2', 'MED3', 'MED4', 'MED5', 'MED6', 'MED7', 'MED8', 'MED9', 'MED10', 'NCMED1', 'NCMED2', 'NCMED3', 'NCMED4', 'NCMED5', 'NCMED6', 'NCMED7', 'NCMED8', 'NCMED9', 'NCMED10', 'NUMMED', 'NUMNEW', 'NUMCONT', 'NOPROVID', 'PHYS', 'PHYSASST', 'NPNMW', 'RNLPN', 'MHP', 'OTHPROV', 'PROVNONE', 'TIMEMD', 'NODISP', 'REFOTHMD', 'RETAPPT', 'ERADMHOS', 'OTHDISP', 'CHOL', 'CHOLRES', 'DAYDCHOL', 'HDL', 'HDLRES', 'DAYDHDL', 'LDL', 'LDLRES', 'DAYDLDL', 'LIPIDERR', 'LDLDIFF', 'TGS', 'TGSRES', 'DAYDTGS', 'A1C', 'A1CRES', 'DAYDA1C', 'FBG', 'FBGRES', 'DAYDFBG', 'AGEFLAG', 'GESTFL', 'BDATEFL', 'SEXFL', 'ETHNICFL', 'RACERFL', 'SENBEFL', 'PASTFL', 'TIMEMDFL', 'PHYCODE', 'PATCODE', 'SPECR_14', 'SPECR_17', 'SPECR17_SPECCAT', 'SPECCAT', 'MDDO', 'RETYPOFFR', 'SOLO', 'EMPSTAT', 'OWNSR', 'PATEVEN', 'NHVISR', 'HOMVISR', 'HOSVISR', 'TELCONR', 'ECONR', 'EBILLREC', 'EINS', 'EINSHOW', 'EINSFAST', 'EMEDREC', 'EMRINS', 'MUINC', 'INTENDYR', 'EDEMOG', 'EDEMOGR', 'EPROLST', 'EPROLSTR', 'EVITAL', 'EVITALR', 'ESMOKE', 'ESMOKER', 'EPNOTES', 'EPNOTESR', 'EMEDALG', 'EMEDALGR', 'ECPOE', 'ECPOER', 'ESCRIP', 'ESCRIPR', 'EWHOPRACP', 'EWHOOTHP', 'EWHOUNKP', 'EWHOREFP', 'EWARN', 'EWARNR', 'EREMIND', 'EREMINDR', 'ESETS', 'ESETSR', 'ECTOE', 'ECTOER', 'EORDER', 'EORDERR', 'EWHOPRACL', 'EWHOOTHL', 'EWHOUNKL', 'EWHOREFL', 'ERESULT', 'ERESULTR', 'EGRAPH', 'EGRAPHR', 'EIMGRES', 'EIMGRESR', 'EQOC', 'EQOCR', 'ECQM', 'ECQMR', 'EGENLIST', 'EGENLISTR', 'EIMMREG', 'EIMMREGR', 'EMUREP', 'EMUREPR', 'ESUM', 'ESUMR', 'EMSG', 'EMSGR', 'EHLTHINFO', 'EHLTHINFOR', 'ESHARE', 'ESHAREEHR', 'ESHAREWEB', 'ESHAREOTH', 'ESHAREUNK', 'ESHAREREF', 'LABRES1', 'LABRES2', 'LABRES3', 'LABRES4', 'LABRESUNK', 'LABRESREF', 'IMAGREP1', 'IMAGREP2', 'IMAGREP3', 'IMAGREP4', 'IMAGREPUNK', 'IMAGREPREF', 'PTPROB1', 'PTPROB2', 'PTPROB3', 'PTPROB4', 'PTPROBUNK', 'PTPROBREF', 'MEDLIST1', 'MEDLIST2', 'MEDLIST3', 'MEDLIST4', 'MEDLISTUNK', 'MEDLISTREF', 'ALGLIST1', 'ALGLIST2', 'ALGLIST3', 'ALGLIST4', 'ALGLISTUNK', 'ALGLISTREF', 'SUMREC', 'CONSULTOUT', 'CONSULTOUTE', 'CONSULTIN', 'CONSULTINE', 'INPTINFO',  ...
# ['Month of visit', 'Day of week of visit', 'Patient age in years', 'Patient age recode', 'Age in days for patients less than 1 year', 'Patient sex', 'Is patient pregnant?', 'Gestation week', 'Patient ethnicity - unimputed', 'Patient race - unimputed', 'Patient ethnicity - imputed', ' Patient race - imputed', 'Race/ethnicity - imputed', 'Expected source of payment for visit: No answer to item', 'Expected source of payment for visit: Private insurance', 'Expected source of payment for visit: Medicare', 'Expected source of payment for visit: Medicaid', 'Expected source of payment for visit: Workers Compensation', 'Expected source of payment for visit: Self-pay', 'Expected source of payment for visit: No Charge/Charity', 'Expected source of payment for visit: Other', 'Expected source of payment for visit: Unknown', 'Type of payment (recoded from multiple sources using hierarchy)', 'Tobacco Use', 'Is visit related to injury/poisoning/adverse effect? Broad recode', 'Is visit related to injury/poisoning? Recoded version #1', 'Is visit related to injury/poisoning? Recoded version #2', 'Is visit related to injury/poisoning/adverse effect? 2012 format', 'Is visit related to injury/poisoning/adverse effect? 2012 format, recoded version #1', 'Is visit related to injury/poisoning/adverse effect? 2012 format, recoded version #2', 'Is injury/poisoining unintentional or intentional?', 'Is visit related to any of the following? Broad recode using 2010 format', 'Is visit related to any of the following? Recoded version #1', 'Is visit related to any of the following? Recoded version #2', "Patient's reason for visit #1", "Patient's reason for visit #2", "Patient's reason for visit #3", 'Reason for visit #1 - 3 digit', 'Reason for visit #2 - 3 digit', 'Reason for visit #3 - 3 digit', "Are you the patient's primary care physician?", 'Was patient referred for visit?', 'Has this patient been seen in your practice before?', 'If yes, how many past visits in the last 12 months?', 'Major reason for this visit', 'Diagnosis #1', 'Is diagnosis #1 probable, questionable or rule out?', 'Diagnosis #2', 'Is diagnosis $2 probable, questionable or rule out?', 'Diagnosis #3', 'Is diagnosis #3 probable, questionable or rule out?', 'Diagnosis #1 - 3 digit', 'Diagnosis #2 - 3 digit', 'Diagnosis #3 - 3 digit', 'Diagnosis #1 - numeric recode', 'Diagnosis #2 - numeric recode', 'Diagnosis #3 - numeric recode', 'Does patient now have: Arthritis', 'Does patient  now have: Asthma', 'Asthma severity', 'Asthma control', 'Does patient now have: Cancer', 'Type of cancer', 'Does patient now have: Cerebrovascular disease', 'Does patient now have: COPD', 'Does patient now have: Chronic renal failure', 'Does patient now have: Congestive heart failure', ' Does patient now have: Depression', 'Does patient now have: Diabetes', 'Does patient now have: Hyperlipidemia', 'Does patient now have: Hypertension', 'Does patient now have: Ischemic heart disease', 'Does patient now have: Obesity', 'Does patient now have: Osteoporosis', 'Does patient now have: None of the above', 'Total number of chronic conditions', 'Was height taken?', 'Height in inches', 'Was weight taken?', 'Weight in pounds', 'Body mass index - calculated from height and weight', 'Was temperature taken?', 'Temperature (in Fahrenheit)', 'Was blood pressure taken?', 'Systolic blood pressure', 'Diastolic blood pressure', 'Were any services ordered or provided at this visit? (Based on SERVICES item only, does not include vital signs)', 'Breast exam', 'Depression Screening', 'Foot exam', 'General physical exam', 'Neurologic', 'Pelvic exam', 'Rectal exam', 'Retinal exam', 'Skin exam', 'CBC (complete blood count)', 'Glucose', 'HgbA1C', 'Lipid profile', 'PSA (prostate specific antigen) test', 'Any imaging', 'Bone mineral density', 'CT Scan', 'Echocardiogram', 'Other ultrasound', 'Mammography', 'MRI', 'X-ray', 'Other imaging', 'Audiometry', 'Biopsy', 'Biopsy provided', 'Cardiac stress test', 'Chlamydia test', 'Colonoscopy', 'EKG/ECG' ...
# {'VMONTH': 'labels0', 'VDAYR': 'labels1', 'AGE': 'labels2', 'AGER': 'labels3', 'AGEDAYS': 'labels4', 'SEX': 'labels5', 'PREGNANT': 'labels6', 'GESTWK': 'labels7', 'ETHUN': 'labels8', 'RACEUN': 'labels9', 'ETHIM': 'labels10', 'RACER': 'labels11', 'RACERETH': 'labels12', 'NOPAY': 'labels13', 'PAYPRIV': 'labels14', 'PAYMCARE': 'labels14', 'PAYMCAID': 'labels14', 'PAYWKCMP': 'labels14', 'PAYSELF': 'labels14', 'PAYNOCHG': 'labels14', 'PAYOTH': 'labels14', 'PAYDK': 'labels14', 'PAYTYPER': 'labels15', 'USETOBAC': 'labels16', 'INJURY': 'labels17', 'INJR1': 'labels17', 'INJR2': 'labels17', 'INJPOISAD': 'labels18', 'INJPOISADR1': 'labels18', 'INJPOISADR2': 'labels18', 'INTENT': 'labels19', 'INJDET_TRD': 'labels20', 'INJDETR1_TRD': 'labels20', 'INJDETR2_TRD': 'labels20', 'RFV1': 'labels21', 'RFV2': 'labels21', 'RFV3': 'labels21', 'RFV13D': 'labels22', 'RFV23D': 'labels22', 'RFV33D': 'labels22', 'PRIMCARE': 'labels23', 'REFER': 'labels24', 'SENBEFOR': 'labels25', 'PASTVIS': 'labels26', 'MAJOR': 'labels27', 'DIAG1': 'labels28', 'PRDIAG1': 'labels29', 'DIAG2': 'labels28', 'PRDIAG2': 'labels29', 'DIAG3': 'labels28', 'PRDIAG3': 'labels29', 'DIAG13D': 'labels30', 'DIAG23D': 'labels30', 'DIAG33D': 'labels30', 'ARTHRTIS': 'labels14', 'ASTHMA': 'labels14', 'ASTH_SEV': 'labels31', 'ASTH_CON': 'labels32', 'CANCER': 'labels14', 'CASTAGE': 'labels33', 'CEBVD': 'labels14', 'COPD': 'labels14', 'CRF': 'labels14', 'CHF': 'labels14', 'DEPRN': 'labels14', 'DIABETES': 'labels14', 'HYPLIPID': 'labels14', 'HTN': 'labels14', 'IHD': 'labels14', 'OBESITY': 'labels14', 'OSTPRSIS': 'labels14', 'NOCHRON': 'labels34', 'HTTAKE': 'labels14', 'HTIN': 'labels35', 'WTTAKE': 'labels14', 'WTLB': 'labels36', 'BMI': 'labels37', 'TEMPTAKE': 'labels14', 'TEMPF': 'labels38', 'BLODPRES': 'labels14', 'BPSYS': 'labels39', 'BPDIAS': 'labels40', 'SERVICES': 'labels41', 'BREAST': 'labels14', 'DEPRESS': 'labels14', 'FOOT': 'labels14', 'PHYSICAL': 'labels14', 'NEURO': 'labels14', 'PELVIC': 'labels14', 'RECTAL': 'labels14', 'RETINAL': 'labels14', 'SKIN': 'labels14', 'CBC': 'labels14', 'GLUCOSE': 'labels14', 'HGBA': 'labels14', 'CHOLEST': 'labels14', 'PSA': 'labels14', 'ANYIMAGE': 'labels14', 'BONEDENS': 'labels14', 'CATSCAN': 'labels14', 'ECHOCARD': 'labels14', 'OTHULTRA': 'labels14', 'MAMMO': 'labels14', 'MRI': 'labels14', 'XRAY': 'labels14', 'OTHIMAGE': 'labels14', 'AUDIO': 'labels14', 'BIOPSY': 'labels14', 'BIOPROV': 'labels42', 'CARDIAC': 'labels14', 'CHLAMYD': 'labels14', 'COLON': 'labels14', 'EKG': 'labels14', 'EEG': 'labels14', 'EMG': 'labels14', 'EXCISION': 'labels14', 'EXCIPROV': 'labels42', 'FETAL': 'labels14', 'HIVTEST': 'labels14', 'HPVDNA': 'labels14', 'PAP': 'labels14', 'PEAK': 'labels14', 'PREGTEST': 'labels14', 'SIGMOID': 'labels14', 'SIGPROV': 'labels42', 'SPIRO': 'labels14', 'TONO': 'labels14', 'URINE': 'labels14', 'SIGCOLON': 'labels43', 'CSW': 'labels14', 'CAM': 'labels14', 'DME': 'labels14', 'HOMEHLTH': 'labels14', 'MENTAL': 'labels14', 'PT': 'labels14', 'PSYCHOTH': 'labels14', 'RADTHER': 'labels14', 'WOUND': 'labels14', 'ASTHMAED': 'labels14', 'DIETNUTR': 'labels14', 'EXERCISE': 'labels14', 'FAMPLAN': 'labels14', 'GRWTHDEV': 'labels14', 'INJPREV': 'labels14', 'STRESMGT': 'labels14', 'TOBACED': 'labels14', 'WTREDUC': 'labels14', 'OTHSERV': 'labels14', 'PROC1': 'labels44', 'PROC2': 'labels44', 'PROC3': 'labels44', 'PROC4': 'labels44', 'PROC5': 'labels44', 'PROC6': 'labels44', 'PROC7': 'labels44', 'PROC8': 'labels44', 'PROC9': 'labels44', 'PROC13D': 'labels45', 'PROC23D': 'labels45', 'PROC33D': 'labels45', 'PROC43D': 'labels45', 'PROC53D': 'labels45', 'PROC63D': 'labels45', 'PROC73D': 'labels45', 'PROC83D': 'labels45', 'PROC93D': 'labels45', 'PROC12D': 'labels46', 'PROC22D': 'labels46', 'PROC32D': 'labels46', 'PROC42D': 'labels46', 'PROC52D': 'labels46', 'PROC62D': 'labels46', 'PROC72D': 'labels46', 'PROC82D': 'labels46', 'PROC92D': 'labels46', 'EXAM': 'labels47', 'ALLSERV': 'labels41', 'MED': 'labels48', 'MED1': 'labels49', 'MED2': 'labels49', 'MED3': 'labels49', 'ME ...
# {'labels0': {1.0: 'January', 2.0: 'February', 3.0: 'March', 4.0: 'April', 5.0: 'May', 6.0: 'June', 7.0: 'July', 8.0: 'August', 9.0: 'September', 10.0: 'October', 11.0: 'November', 12.0: 'December'}, 'labels1': {1.0: 'Sunday', 2.0: 'Monday', 3.0: 'Tuesday', 4.0: 'Wednesday', 5.0: 'Thursday', 6.0: 'Friday', 7.0: 'Saturday'}, 'labels2': {0.0: 'Under 1 year', 92.0: '92 years or older'}, 'labels3': {1.0: 'Under 15 years', 2.0: '15-24 years', 3.0: '25-44 years', 4.0: '45-64 years', 5.0: '65-74 years', 6.0: '75 years and over'}, 'labels4': {-7.0: 'Not applicable', 0.0: 'Less than 1 day'}, 'labels5': {1.0: 'Female', 2.0: 'Male'}, 'labels6': {-9.0: 'Blank', -8.0: 'Unknown', -7.0: 'Not applicable', 1.0: 'Yes', 2.0: 'No'}, 'labels7': {-9.0: 'Blank', -8.0: 'Unknown', -7.0: 'Not applicable'}, 'labels8': {-9.0: 'Blank', 1.0: 'Hispanic or Latino', 2.0: 'Not Hispanic or Latino'}, 'labels9': {-9.0: 'Blank', 1.0: 'White Only', 2.0: 'Black/African American Only', 3.0: 'Asian Only', 4.0: 'Native Hawaiian/Oth Pac Isl Only', 5.0: 'American Indian/Alaska Native Only', 6.0: 'More than one race reported'}, 'labels10': {1.0: 'Hispanic or Latino', 2.0: 'Not Hispanic or Latino'}, 'labels11': {1.0: 'White', 2.0: 'Black', 3.0: 'Other'}, 'labels12': {1.0: 'Non-Hispanic White', 2.0: 'Non-Hispanic Black', 3.0: 'Hispanic', 4.0: 'Non-Hispanic Other'}, 'labels13': {0.0: 'One or more categories marked', 1.0: 'No categories marked'}, 'labels14': {0.0: 'No', 1.0: 'Yes'}, 'labels15': {-9.0: 'All sources of payment are blank', -8.0: 'Unknown', 1.0: 'Private insurance', 2.0: 'Medicare', 3.0: 'Medicaid or CHIP', 4.0: "Worker's compensation", 5.0: 'Self-pay', 6.0: 'No charge/Charity', 7.0: 'Other'}, 'labels16': {-9.0: 'Blank', -8.0: 'Unknown', 1.0: 'Not current', 2.0: 'Current'}, 'labels17': {-9.0: 'Blank', -8.0: 'Unknown', 0.0: 'No', 1.0: 'Yes'}, 'labels18': {-9.0: 'Blank', -8.0: 'Unknown', 1.0: 'Yes, injury/trauma', 2.0: 'Yes, poisoning', 3.0: 'Yes, adverse effect of medical treatment', 4.0: 'No'}, 'labels19': {-9.0: 'Blank', -8.0: 'Unknown', 1.0: 'Unintentional', 2.0: 'Intentional'}, 'labels20': {-9.0: 'Blank', -8.0: 'Unknown', -5.0: 'Intentionality does not apply', 1.0: 'Unintentional injury/poisoning', 2.0: 'Intentional injury/poisoning', 3.0: 'Injury/poisoning - unknown intent', 4.0: 'Adv effect of med/surg care/medicinal drug', 5.0: 'No injury'}, 'labels21': {-9.0: 'Blank', 10050.0: 'Chills', 10100.0: 'Fever', 10120.0: 'Other symptoms of body temperature', 10121.0: 'Feeling cold', 10122.0: 'Feeling hot', 10123.0: 'Feeling hot and cold', 10150.0: 'Tiredness, exhaustion', 10200.0: 'General weakness', 10250.0: 'General ill feeling', 10300.0: 'Fainting (syncope)', 10350.0: 'Symptoms of fluid abnormalities', 10351.0: 'Edema', 10352.0: 'Excessive sweating, perspiration', 10353.0: 'Excessive thirst', 10400.0: 'Weight gain', 10450.0: 'Weight loss', 10451.0: 'Recent weight loss', 10452.0: 'Underweight', 10460.0: 'Symptoms of face, not elsewhere class...', 10500.0: 'Chest pain and related symptoms', 10501.0: 'Chest pain', 10502.0: 'Chest discomfort, pressure, tightness', 10503.0: 'Burning sensation in the chest', 10550.0: 'Pain, specified site not referable to...', 10551.0: 'Rib pain', 10552.0: 'Side pain, flank pain', 10553.0: 'Groin pain', 10554.0: 'Facial pain', 10600.0: 'Pain and related symptoms, generalize...', 10601.0: 'Pain, unspecified', 10602.0: 'Cramps, spasms, site unspecified', 10603.0: 'Stiffness, site unspecified', 10650.0: 'Tumor or mass, site unspecified', 10651.0: 'Internal mass, NOS', 10660.0: 'Lesion, internal NOS (excludes brain ...', 10700.0: 'Bleeding, multiple or unspecified sites', 10750.0: 'Symptoms of growth and developmental ...', 10751.0: 'Lack of growth', 10752.0: 'Excessive growth', 10800.0: 'General symptoms of infants, NEC', 10801.0: 'Infant crying too much, fussy, fidget...', 10802.0: 'Infant regurgitation, spitting up', 10803.0: 'Infant feeding problem', 10850.0: 'General or unspecified nonviral infec...', 10900.0: 'Allergy, NOS', 10950.0 ...

# %%
# More meta data from the SPSS file
print(meta.number_rows)
print(meta.number_columns)
print(meta.file_label)
print(meta.file_encoding)
# Out:
# 76330
# 624
# None
# UTF-8

# %%
#print(meta.variable_value_labels)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(Counter(trim_df['REGION']))
print(Counter(trim_df['MSA']))
print(Counter(trim_df['RETYPOFF']))
# Out:
# Counter({'South': 47262, 'Midwest': 37136, 'West': 33069, 'Northeast': 24819})
# Counter({'MSA (Metropolitan Statistical Area)': 125431, 'Non-MSA': 16855})
# Counter({'Private solo or group practice': 121157, 'Other': 7819, 'Community health center': 4787, 'Freestanding clinic/urgicenter': 2444, 'Federally qualified health center (FQHC)': 2417, 'Health Maint Org (HMO)/oth prepaid prac': 2090, 'Mental health center': 750, 'Non-federal government clinic': 492, 'Faculty practice plan': 229, 'Federally qualified health ctr (FQHC)': 82, 'Family planning clinic': 19})
# Counter({'Private solo or group practice': 121157, 'Other': 7819, 'Community health center': 4787, 'Freestanding clinic/urgicenter': 2444, 'Federally qualified health center (FQHC)': 2417, 'Health Maint Org (HMO)/oth prepaid prac': 2090, 'Mental health center': 750, 'Non-federal government clinic': 492, 'Faculty practice plan': 229, 'Federally qualified health ctr (FQHC)': 82, 'Family planning clinic': 19})

# %%
# Check if all column names are the same before concatenating dataframes

temp_df2.columns == temp_df.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])
